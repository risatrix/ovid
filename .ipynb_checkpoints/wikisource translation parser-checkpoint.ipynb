# %%
import requests
import json
# from lxml import html, etree
from bs4 import BeautifulSoup


base_url="https://en.wikisource.org/wiki/Translation:Amores/1.15"
r = requests.get(base_url)
print r.status_code

html_doc = r.text
soup = BeautifulSoup(html_doc, 'html.parser')

poems = soup.find_all("div", class_="poem")
poem = poems[0]
poem_dict = {}
breaks = poem.find_all("br")
num_lines = len(breaks)
print num_lines
# you'd think you could use enumerate, but no, if you do that you lose the BS4 methods on the list items
# boo
count = 0
poem_dict = {}
lines = []

def add_line(obj,method,count):
    line_dict = {}
    line_dict["line_index"] = index
    line_dict["text"] = obj.method
    print line_dict["text"]
    lines.append{line_dict}

for br in breaks:
    count += 1
    if count == num_lines:
        line_dict = {}
        line_dict["line_index"] = count
        line_dict["text"] = br.previousSibling
        lines.append(line_dict)
        
        last_line_dict = {}
        last_line_dict["line_index"] = count+1
        line_dict["text"] = br.nextSibling
        lines.append{line_dict}
    else:
        add_line(br,previousSibling,count)
#         line_dict = {}
#         line_dict["line_index"] = index
#         line_dict["text"] = br.previousSibling
#         lines.append{line_dict}
        
        
        
#     if index==num_lines:
#         print br.nextSibling
#     else:
#         print br.previousSibling
# print poem.text
# tree = etree.HTML(page.text)
# element = tree.xpath('./body/form/table[3]/tr/td/table[5]')
# tree = html.fromstring(page.content)

# poem = tree.xpath('//div[@class="buyer-name"]/text()')
# print 'Poem: ', poem
# Out:
# 200
# 41
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
# <br/>
# None
#
#
# So, even when the final flame has consumed me,
#
#     I shall live, and a considerable part of me will survive.
